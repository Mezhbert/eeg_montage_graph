# %%
from src import scripts
from src.constants import BASE_PATH, IMG_PATH, CHANS_COORDS

# %%
FREQUENCIES = ['delta [3, 4]', 'theta [4, 8]', 'alpha [8, 13]', 
               'beta-1 [13.0, 16.0]', 'beta-2 [16.0, 20.0]', 'beta-3 [20.0, 28.0]', 
               'gamma[30.0, 50.0]']

TIME_PERIODS = ['0 - 100', '100 - 200', '200 - 300',
                '300 - 400', '400 - 500', '500 - 600', '800-1000']

df_paths = scripts.get_libs_paths(BASE_PATH)

# %%
# первые 4 частоты
scripts.draw_plots(TIME_PERIODS=TIME_PERIODS,
           FREQUENCIES=FREQUENCIES,
           df_paths=df_paths,
           CHANS_COORDS=CHANS_COORDS,
           IMG_PATH=IMG_PATH,
           which_freq_to_draw=(1,5))

# %%
# по всем частотам
scripts.draw_plots(TIME_PERIODS=TIME_PERIODS,
                   FREQUENCIES=FREQUENCIES,
                   df_paths=df_paths,
                   CHANS_COORDS=CHANS_COORDS,
                   IMG_PATH=IMG_PATH)
