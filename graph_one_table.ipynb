# %%
from src import scripts
from src.constants import IMG_PATH, CHANS_COORDS

# %%
# P-value, которое будет использоваться для отбора связий между отведениями
TRESH = 0.005

# %%
 # путь до нужной таблице
PATH = 'libs/ResultsWPLIConn800-1000ms1e-05.xlsx'

# необходимо указать временной период
TIME_PERIOD = '0 - 100'

# %%
# первые три частоты
scripts.draw_plot_one_tab(path=PATH,
                          name='0 - 100',
                          IMG_PATH=IMG_PATH,
                          CHANS_COORDS=CHANS_COORDS,
                          which_columns=[1,2,3])

# %%
# для всех частот горизонтально
scripts.draw_plot_one_tab(path=PATH,
                          name='0 - 100',
                          IMG_PATH=IMG_PATH,
                          CHANS_COORDS=CHANS_COORDS,)

# %%
# для всех частот вертикально
scripts.draw_plot_one_tab(path=PATH,
                          name='0 - 100',
                          IMG_PATH=IMG_PATH,
                          CHANS_COORDS=CHANS_COORDS,
                          vertical_layout=True,
                          tight_layout=False)
